# %%
import pandas as pd#importing pandas library

# %%
df=pd.read_csv("pokemon_data.csv")#importing a file

# %%
df.head(5)#checking the data
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.columns#checking columns values
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
type(df)#checking the data type
# Out:
# pandas.core.frame.DataFrame

# %%
#ACESSING THE COLUMNS

# %%
df.Name
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df["#"].head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    3
# 4    4
# Name: #, dtype: int64

# %%
df[["Type 1","Type 2","HP"]]
# Out:
#       Type 1  Type 2  HP
# 0      Grass  Poison  45
# 1      Grass  Poison  60
# 2      Grass  Poison  80
# 3      Grass  Poison  80
# 4       Fire     NaN  39
# ..       ...     ...  ..
# 795     Rock   Fairy  50
# 796     Rock   Fairy  50
# 797  Psychic   Ghost  80
# 798  Psychic    Dark  80
# 799     Fire   Water  80
#
# [800 rows x 3 columns]

# %%
#changing the index to an exsisting column**this changes the dataframe

# %%
ds=df.set_index("Type 1")
ds.head()
# Out:
#         #                   Name  Type 2  HP  Attack  Defense  Sp. Atk  \
# Type 1
# Grass   1              Bulbasaur  Poison  45      49       49       65
# Grass   2                Ivysaur  Poison  60      62       63       80
# Grass   3               Venusaur  Poison  80      82       83      100
# Grass   3  VenusaurMega Venusaur  Poison  80     100      123      122
# Fire    4             Charmander     NaN  39      52       43       60
#
#         Sp. Def  Speed  Generation  Legendary
# Type 1
# Grass        65     45           1      False
# Grass        80     60           1      False
# Grass       100     80           1      False
# Grass       120     80           1      False
# Fire         50     65           1      False

# %%
#accessing rows using the index values

# %%
ds.loc["Fire"]
# Out:
#           #                       Name    Type 2   HP  Attack  Defense  \
# Type 1
# Fire      4                 Charmander       NaN   39      52       43
# Fire      5                 Charmeleon       NaN   58      64       58
# Fire      6                  Charizard    Flying   78      84       78
# Fire      6  CharizardMega Charizard X    Dragon   78     130      111
# Fire      6  CharizardMega Charizard Y    Flying   78     104       78
# Fire     37                     Vulpix       NaN   38      41       40
# Fire     38                  Ninetales       NaN   73      76       75
# Fire     58                  Growlithe       NaN   55      70       45
# Fire     59                   Arcanine       NaN   90     110       80
# Fire     77                     Ponyta       NaN   50      85       55
# Fire     78                   Rapidash       NaN   65     100       70
# Fire    126                     Magmar       NaN   65      95       57
# ...

# %%
#using the iloc & loc functions

# %%
df.loc[1]
# Out:
# #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object

# %%
df.loc[[1,2,3]] #access rows
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df.loc[4:10]#acess a range of rows
# Out:
#     #                       Name Type 1  Type 2  Legendary  Generation  HP  \
# 4   4                 Charmander   Fire     NaN      False           1  39
# 5   5                 Charmeleon   Fire     NaN      False           1  58
# 6   6                  Charizard   Fire  Flying      False           1  78
# 7   6  CharizardMega Charizard X   Fire  Dragon      False           1  78
# 8   6  CharizardMega Charizard Y   Fire  Flying      False           1  78
# 9   7                   Squirtle  Water     NaN      False           1  44
# 10  8                  Wartortle  Water     NaN      False           1  59
#
#     Attack  Defense  Sp. Atk  Sp. Def  Speed  TotaL
# 4       52       43       60       50     65    309
# 5       64       58       80       65     80    405
# 6       84       78      109       85    100    534
# 7      130      111      130       85    100    634
# 8      104       78      159      115    100    634
# 9       48       65       50       64     43    314
# ...

# %%
df.iloc[1,3]#access a specific location
# Out:
# 'Poison'

# %%
#Adding/droping columns

# %%
df['Total']=df["HP"]+df["Attack"]+df['Defense']+df['Sp. Atk']+df["Sp. Def"]+df["Speed"]#adding column total

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df=df.drop(columns=["Total"])#droping the total columns

# %%
df["TotaL"]=df.iloc[:,4:10].sum(axis=1)# alternative way to add a column

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  TotaL
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
#rearrangging the order of columns

# %%
col=list(df.columns.values)

# %%
df=df[col[0:4]+[col[-2]]+[col[-3]]+col[4:10]+col[12:13]]

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Legendary  Generation  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison      False           1  45      49
# 1  2                Ivysaur  Grass  Poison      False           1  60      62
# 2  3               Venusaur  Grass  Poison      False           1  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison      False           1  80     100
# 4  4             Charmander   Fire     NaN      False           1  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  TotaL
# 0       49       65       65     45    318
# 1       63       80       80     60    405
# 2       83      100      100     80    525
# 3      123      122      120     80    625
# 4       43       60       50     65    309

# %%
#sorting & Filtering data

# %%
df.describe() #describing the data
# Out:
#                 #  Generation          HP      Attack     Defense     Sp. Atk  \
# count  800.000000   800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750     3.32375   69.258750   79.001250   73.842500   72.820000
# std    208.343798     1.66129   25.534669   32.457366   31.183501   32.722294
# min      1.000000     1.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000     2.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000     3.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000     5.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000     6.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed      TotaL
# count  800.000000  800.000000  800.00000
# mean    71.902500   68.277500  435.10250
# std     27.828916   29.060474  119.96304
# min     20.000000    5.000000  180.00000
# 25%     50.000000   45.000000  330.00000
# ...

# %%
df.sort_values('HP')
# Out:
#        #       Name   Type 1 Type 2  Legendary  Generation   HP  Attack  \
# 316  292   Shedinja      Bug  Ghost      False           3    1      90
# 55    50    Diglett   Ground    NaN      False           1   10      55
# 139  129   Magikarp    Water    NaN      False           1   20      10
# 388  355    Duskull    Ghost    NaN      False           3   20      40
# 487  439   Mime Jr.  Psychic  Fairy      False           4   20      25
# ..   ...        ...      ...    ...        ...         ...  ...     ...
# 655  594  Alomomola    Water    NaN      False           5  165      75
# 351  321    Wailord    Water    NaN      False           3  170      90
# 217  202  Wobbuffet  Psychic    NaN      False           2  190      33
# 121  113    Chansey   Normal    NaN      False           1  250       5
# 261  242    Blissey   Normal    NaN      False           2  255      10
#
#      Defense  Sp. Atk  Sp. Def  Speed  TotaL
# 316       45       30       30     40    236
# ...

# %%
df.sort_values(["Name","HP"],ascending=[1,0])
# Out:
#        #                     Name   Type 1  Type 2  Legendary  Generation  \
# 510  460                Abomasnow    Grass     Ice      False           4
# 511  460  AbomasnowMega Abomasnow    Grass     Ice      False           4
# 68    63                     Abra  Psychic     NaN      False           1
# 392  359                    Absol     Dark     NaN      False           3
# 393  359          AbsolMega Absol     Dark     NaN      False           3
# ..   ...                      ...      ...     ...        ...         ...
# 632  571                  Zoroark     Dark     NaN      False           5
# 631  570                    Zorua     Dark     NaN      False           5
# 46    41                    Zubat   Poison  Flying      False           1
# 695  634                 Zweilous     Dark  Dragon      False           5
# 794  718         Zygarde50% Forme   Dragon  Ground       True           6
#
#       HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  TotaL
# ...

# %%
df.loc[(df["HP"]>=42) & (df["Attack"]==150)] #Filtering(and)
# Out:
#        #                   Name   Type 1    Type 2  Legendary  Generation  \
# 19    15  BeedrillMega Beedrill      Bug    Poison      False           1
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN       True           1
# 229  212      ScizorMega Scizor      Bug     Steel      False           2
# 283  260  SwampertMega Swampert    Water    Ground      False           3
# 393  359        AbsolMega Absol     Dark       NaN      False           3
# 422  382    KyogrePrimal Kyogre    Water       NaN       True           3
# 423  383                Groudon   Ground       NaN       True           3
# 425  384               Rayquaza   Dragon    Flying       True           3
# 428  386     DeoxysNormal Forme  Psychic       NaN       True           3
# 707  644                 Zekrom   Dragon  Electric       True           5
# 750  681   AegislashBlade Forme    Steel     Ghost      False           6
#
#       HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  TotaL
# ...

# %%
df.loc[(df["Type 1"]=="Bug")|(df["Type 2"]=="Ghost")]#filtering(or)
# Out:
#        #                   Name   Type 1  Type 2  Legendary  Generation  HP  \
# 13    10               Caterpie      Bug     NaN      False           1  45
# 14    11                Metapod      Bug     NaN      False           1  50
# 15    12             Butterfree      Bug  Flying      False           1  60
# 16    13                 Weedle      Bug  Poison      False           1  40
# 17    14                 Kakuna      Bug  Poison      False           1  45
# ..   ...                    ...      ...     ...        ...         ...  ..
# 748  679                Honedge    Steel   Ghost      False           6  45
# 749  680               Doublade    Steel   Ghost      False           6  59
# 750  681   AegislashBlade Forme    Steel   Ghost      False           6  60
# 751  681  AegislashShield Forme    Steel   Ghost      False           6  60
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True           6  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  TotaL
# ...

# %%
df.loc[df["Name"].str.contains("pie")]#using the str.contains () to filter
# Out:
#      #      Name Type 1 Type 2  Legendary  Generation  HP  Attack  Defense  \
# 13  10  Caterpie    Bug    NaN      False           1  45      30       35
#
#     Sp. Atk  Sp. Def  Speed  TotaL
# 13       20       20     45    195

# %%
df.loc[~df["Name"].str.contains("pie")]#using the str.contains () & the the inverse symbol to filter
# Out:
#        #                   Name   Type 1  Type 2  Legendary  Generation  HP  \
# 0      1              Bulbasaur    Grass  Poison      False           1  45
# 1      2                Ivysaur    Grass  Poison      False           1  60
# 2      3               Venusaur    Grass  Poison      False           1  80
# 3      3  VenusaurMega Venusaur    Grass  Poison      False           1  80
# 4      4             Charmander     Fire     NaN      False           1  39
# ..   ...                    ...      ...     ...        ...         ...  ..
# 795  719                Diancie     Rock   Fairy       True           6  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True           6  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True           6  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True           6  80
# 799  721              Volcanion     Fire   Water       True           6  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  TotaL
# ...

# %%
#conditional changes

# %%
df.loc[df["Type 1"]=="Grass","Type 1"]="Weed"
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary  Generation  HP  \
# 0      1              Bulbasaur     Weed  Poison      False           1  45
# 1      2                Ivysaur     Weed  Poison      False           1  60
# 2      3               Venusaur     Weed  Poison      False           1  80
# 3      3  VenusaurMega Venusaur     Weed  Poison      False           1  80
# 4      4             Charmander     Fire     NaN      False           1  39
# ..   ...                    ...      ...     ...        ...         ...  ..
# 795  719                Diancie     Rock   Fairy       True           6  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True           6  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True           6  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True           6  80
# 799  721              Volcanion     Fire   Water       True           6  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  TotaL
# ...

# %%
df.loc[df["Type 1"]=="Weed",["Type 1","Generation"]]=["Grass","0"]
df
# Out:
#        #                   Name   Type 1  Type 2  Legendary Generation  HP  \
# 0      1              Bulbasaur    Grass  Poison      False          0  45
# 1      2                Ivysaur    Grass  Poison      False          0  60
# 2      3               Venusaur    Grass  Poison      False          0  80
# 3      3  VenusaurMega Venusaur    Grass  Poison      False          0  80
# 4      4             Charmander     Fire     NaN      False          1  39
# ..   ...                    ...      ...     ...        ...        ...  ..
# 795  719                Diancie     Rock   Fairy       True          6  50
# 796  719    DiancieMega Diancie     Rock   Fairy       True          6  50
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True          6  80
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True          6  80
# 799  721              Volcanion     Fire   Water       True          6  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  TotaL
# ...

# %%
#groupby

# %%
df=pd.read_csv("pokemon_data.csv")

# %%
df.groupby("Type 1").mean()
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Electric  363.500000  59.795455   69.090909   66.295455  90.022727  73.704545
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# ...

# %%
df.groupby("Type 1").mean().sort_values("Defense",ascending=1)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Normal    319.173469  77.275510   73.469388   59.846939  55.816327  63.724490
# Fairy     449.529412  74.117647   61.529412   65.705882  78.529412  84.705882
# Fighting  363.851852  69.851852   96.777778   65.925926  53.111111  64.703704
# Flying    677.750000  70.750000   78.750000   66.250000  94.250000  72.500000
# Electric  363.500000  59.795455   69.090909   66.295455  90.022727  73.704545
# Psychic   380.807018  70.631579   71.456140   67.684211  98.403509  86.280702
# Fire      327.403846  69.903846   84.769231   67.769231  88.980769  72.211538
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# ...
